# %% [markdown]
# Dynamic stock modelling of steel production

# %%
# Import packages
import pandas as pd
import numpy as np
import openpyxl
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns

# %% [markdown]
# Import data
